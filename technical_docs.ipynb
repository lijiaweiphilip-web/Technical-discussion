# %% [markdown]
# <a href="https://colab.research.google.com/github/lijiaweiphilip-web/Technical-discussion/blob/main/technical_docs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ingest

# %%
def hello():
  return "Hi"
hello()
# Out:
# 'Hi'

# %% [markdown]
# ## EDA

# %% [markdown]
# ### This is a markdown heading
#
# * one
# * two

# %% [markdown]
# ## Modeling

# %% [markdown]
# ## Conclusion
